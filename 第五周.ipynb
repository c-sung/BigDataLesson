# %% [markdown]
# <a href="https://colab.research.google.com/github/c-sung/BigDataLesson/blob/main/%E7%AC%AC%E4%BA%94%E5%91%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("SportsAnalytics")
install.packages("ggpolt2")

library(SportsAnalytics)
library(ggplot2)

NBA1920 <- fetch_NBAPlayerStatistics("19-20")
qplot(FieldGoalsAttempted, TotalPoints, data = NBA1920, color = Position, geom = c("point", "smooth"))
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘ggpolt2’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(TotalPoints, data = NBA1920, fill = Position)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(TotalPoints, data = NBA1920, facets = Position ~ ., binwidth = 100)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted, TotalPoints, data = NBA1920, facets = Position ~ .)
# Out:
# plot without title
