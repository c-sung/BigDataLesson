# %% [markdown]
# <a href="https://colab.research.google.com/github/c-sung/BigDataLesson/blob/main/0420%E6%9C%9F%E4%B8%AD%E8%80%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("SportsAnalytics")
install.packages("ggplot2")

library(SportsAnalytics)
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
NBA1718 <- fetch_NBAPlayerStatistics("17-18")
NBA1718order <- NBA1718[order(NBA1718$GamesPlayed, decreasing = T),]
NBA1718order[1:20, "Name"]
# Out:
#  [1] "Bradley Beal"     "Dragan Bender"    "Bismack Biyombo"  "Dillon Brooks"
#  [5] "Pat Connaughton"  "Raymond Felton"   "Yogi Ferrell"     "Taj Gibson"
#  [9] "Marcin Gortat"    "Joe Ingles"       "Lebron James"     "Tyus Jones"
# [13] "Cory Joseph"      "Khris Middleton"  "Darius Miller"    "Patty Mills"
# [17] "E'twaun Moore"    "Patric Patterson" "Jakob Poeltl"     "Taurean Prince"

# %%
subset(NBA1718, Position == "C")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 3   NBA    Steven Adams     OKL  C        76          2486
# 6   NBA    Cole Aldrich     MIN  C        21            51
# 8   NBA    Jarrett Allen    BRO  C        72          1437
# 15  NBA    Ike Anigbogu     IND  C        11            30
# 23  NBA    Omer Asik        CHI  C        18           180
# 35  NBA    Aron Baynes      BOS  C        81          1487
# 46  NBA    Khem Birch       ORL  C        41           578
# 48  NBA    Bismack Biyombo  ORL  C        82          1491
# 50  NBA    Tarik Black      HOU  C        51           534
# 56  NBA    Andrew Bogut     LAL  C        23           217
# 62  NBA    Tony Bradley     UTA  C         9            29
# 75  NBA    Thomas Bryant    LAL  C        15            71
# 85  NBA    Clint Capela     HOU  C        74          2034
# 91  NBA    Wil Cauley-stein SAC  C        73          2042
# 94  NBA    Tyson Chandler   PHO  C        46          1153
# ...

# %%
NBA1718[grepl("James", NBA1718$Name),]
# Out:
#     League Name          Team Position GamesPlayed TotalMinutesPlayed
# 149 NBA    James Ennis   DET  PG       72          1601
# 195 NBA    James Harden  HOU  SG       72          2547
# 248 NBA    Lebron James  CLE  SF       82          3024
# 249 NBA    Mike James    NOR  PG       36           686
# 257 NBA    James Johnson MIA  PF       73          1944
# 320 NBA    James Mcadoo  PHI  PF        3            18
# 505 NBA    James Webb    BRO  SF       10           120
# 532 NBA    James Young   PHI  SG        6            61
#     FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 149 182             384                 51        153             ⋯  47
# 195 651            1448                265        722             ⋯ 126
# 248 857            1580                149        406             ⋯ 117
# 249 123             320                 26         98             ⋯  28
# 257 309             614                 57        185             ⋯  70
# ...

# %%
qplot(FieldGoalsAttempted, TotalPoints, data = NBA1718, color = Position)
# Out:
# plot without title

# %%
qplot(TotalPoints, data = NBA1718, fill = Position)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(FieldGoalsAttempted, TotalPoints, data = NBA1718, facets = Position ~ .)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted, TotalPoints, data = NBA1718, facets = . ~ Position)
# Out:
# plot without title
